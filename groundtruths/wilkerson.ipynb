# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")
from tqdm.notebook import tqdm
import time
from IPython.display import clear_output

import ee, geemap

# %%
# %load_ext autoreload
# %autoreload 2
import sys  
sys.path.insert(0, '../lib/')

# %%
# %reload_ext autoreload
import sand_classification as sc
import quality_mosaic as qm

# %% [markdown]
# # Part I: Get the locations from Google Drive

# %%
sheet_id = '13nF_pJ02Bd70cDJamuKbvZIkIdJ-kOI4O3Cx9K7Wzos'
# sheet_id = '1XqOtPkiE_Q0dfGSoyxrH730RkwrTczcRbDeJJpqRByQ'
sheet_name = 'wilkerson'
drive_url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
drive_url
# Out:
# 'https://docs.google.com/spreadsheets/d/13nF_pJ02Bd70cDJamuKbvZIkIdJ-kOI4O3Cx9K7Wzos/gviz/tq?tqx=out:csv&sheet=wilkerson'

# %%
output_file_path = '../data/labels/gt-bands.xlsx'

# %%
#Read in a google sheets with the ground truth data from string drive_loc
df = pd.read_csv(drive_url)
df
# Out:
#               ID   Latitude   Longitude   Class        Date     Site  \
# 0    wilkerson-0  19.899304  102.140084    sand  2022-02-25  fluvial
# 1    wilkerson-1  28.858429   70.391257    sand  2021-04-25  fluvial
# 2    wilkerson-2   9.141009    4.797954    sand  2021-04-30  fluvial
# 3    wilkerson-3  25.961395   80.159471    sand  2022-11-30  fluvial
# 4    wilkerson-4  25.397259   85.948165    sand  2020-04-18  fluvial
# 5    wilkerson-5  29.406670   71.567847    sand  2022-10-25  fluvial
# 6    wilkerson-6        NaN         NaN    sand         NaN  fluvial
# 7    wilkerson-7        NaN         NaN    sand         NaN  fluvial
# 8    wilkerson-8        NaN         NaN    sand         NaN  fluvial
# 9    wilkerson-9  15.163073   75.885587    fine  2022-12-16  fluvial
# 10  wilkerson-10        NaN         NaN    fine         NaN  fluvial
# 11  wilkerson-11        NaN         NaN    sand         NaN  fluvial
# 12  wilkerson-12        NaN         NaN    sand         NaN  fluvial
# 13  wilkerson-13        NaN         NaN    sand         NaN  fluvial
# 14  wilkerson-14        NaN         NaN    sand         NaN  fluvial
# 15  wilkerson-15        NaN         NaN    sand         NaN  fluvial
# 16  wilkerson-16        NaN         NaN    sand         NaN  fluvial
# 17  wilkerson-18        NaN         NaN    fine         NaN  fluvial
# 18  wilkerson-19        NaN         NaN    sand         NaN  fluvial
# 19  wilkerson-20        NaN         NaN    sand         NaN  fluvial
# 20  wilkerson-21        NaN         NaN    sand         NaN  fluvial
# 21  wilkerson-22        NaN         NaN    sand         NaN  fluvial
# 22  wilkerson-23        NaN         NaN    sand         NaN  fluvial
# 23  wilkerson-24        NaN         NaN    sand         NaN  fluvial
# 24  wilkerson-25        NaN         NaN    sand         NaN  fluvial
# 25  wilkerson-26        NaN         NaN    sand         NaN  fluvial
# 26  wilkerson-27        NaN         NaN    sand         NaN  fluvial
# 27  wilkerson-28        NaN         NaN    sand         NaN  fluvial
# 28  wilkerson-29        NaN         NaN    sand         NaN  fluvial
# 29  wilkerson-31        NaN         NaN    sand         NaN  fluvial
# 30     chaplin-0  40.633863  -75.464181  gravel  2018-06-15  fluvial
#
#                          Source    Country     D50  Notes  ... Unnamed: 17  \
# 0   Wilkerson and Parker (2011)       Laos   0.310    NaN  ...         NaN
# 1   Wilkerson and Parker (2011)   Pakistan   0.180    NaN  ...         NaN
# 2   Wilkerson and Parker (2011)    Nigeria   0.450    NaN  ...         NaN
# 3   Wilkerson and Parker (2011)      India   0.180    NaN  ...         NaN
# 4   Wilkerson and Parker (2011)      India   0.430    NaN  ...         NaN
# 5   Wilkerson and Parker (2011)   Pakistan   0.170    NaN  ...         NaN
# 6   Wilkerson and Parker (2011)      India   0.100    NaN  ...         NaN
# 7   Wilkerson and Parker (2011)      India   1.600    NaN  ...         NaN
# 8   Wilkerson and Parker (2011)  Australia   0.900    NaN  ...         NaN
# 9   Wilkerson and Parker (2011)      India   0.040    NaN  ...         NaN
# 10  Wilkerson and Parker (2011)      India   0.040    NaN  ...         NaN
# 11  Wilkerson and Parker (2011)      India   0.300    NaN  ...         NaN
# 12  Wilkerson and Parker (2011)  Australia   0.880    NaN  ...         NaN
# 13  Wilkerson and Parker (2011)      India   0.320    NaN  ...         NaN
# 14  Wilkerson and Parker (2011)      India   0.150    NaN  ...         NaN
# 15  Wilkerson and Parker (2011)      India   0.150    NaN  ...         NaN
# 16  Wilkerson and Parker (2011)      India   0.560    NaN  ...         NaN
# 17  Wilkerson and Parker (2011)      India   0.043    NaN  ...         NaN
# 18  Wilkerson and Parker (2011)      India   0.250    NaN  ...         NaN
# 19  Wilkerson and Parker (2011)        NaN   0.310    NaN  ...         NaN
# 20  Wilkerson and Parker (2011)      India   0.340    NaN  ...         NaN
# 21  Wilkerson and Parker (2011)      India   0.630    NaN  ...         NaN
# 22  Wilkerson and Parker (2011)        NaN   0.440    NaN  ...         NaN
# 23  Wilkerson and Parker (2011)      India   0.960    NaN  ...         NaN
# 24  Wilkerson and Parker (2011)      India   1.500    NaN  ...         NaN
# 25  Wilkerson and Parker (2011)      India   0.110    NaN  ...         NaN
# 26  Wilkerson and Parker (2011)      India   4.000    NaN  ...         NaN
# 27  Wilkerson and Parker (2011)      India   0.300    NaN  ...         NaN
# 28  Wilkerson and Parker (2011)      India   0.320    NaN  ...         NaN
# 29  Wilkerson and Parker (2011)      India   2.050    NaN  ...         NaN
# 30               Chaplin (2005)        USA  38.200  118.0  ...         NaN
#
#    Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
# 5          NaN          NaN          NaN          NaN          NaN
# 6          NaN          NaN          NaN          NaN          NaN
# 7          NaN          NaN          NaN          NaN          NaN
# 8          NaN          NaN          NaN          NaN          NaN
# 9          NaN          NaN          NaN          NaN          NaN
# 10         NaN          NaN          NaN          NaN          NaN
# 11         NaN          NaN          NaN          NaN          NaN
# 12         NaN          NaN          NaN          NaN          NaN
# 13         NaN          NaN          NaN          NaN          NaN
# 14         NaN          NaN          NaN          NaN          NaN
# 15         NaN          NaN          NaN          NaN          NaN
# 16         NaN          NaN          NaN          NaN          NaN
# 17         NaN          NaN          NaN          NaN          NaN
# 18         NaN          NaN          NaN          NaN          NaN
# 19         NaN          NaN          NaN          NaN          NaN
# 20         NaN          NaN          NaN          NaN          NaN
# 21         NaN          NaN          NaN          NaN          NaN
# 22         NaN          NaN          NaN          NaN          NaN
# 23         NaN          NaN          NaN          NaN          NaN
# 24         NaN          NaN          NaN          NaN          NaN
# 25         NaN          NaN          NaN          NaN          NaN
# 26         NaN          NaN          NaN          NaN          NaN
# 27         NaN          NaN          NaN          NaN          NaN
# 28         NaN          NaN          NaN          NaN          NaN
# 29         NaN          NaN          NaN          NaN          NaN
# 30         NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 23  Unnamed: 24  Unnamed: 25  Unnamed: 26
# 0           NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN
# 7           NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN
# 9           NaN          NaN          NaN          NaN
# 10          NaN          NaN          NaN          NaN
# 11          NaN          NaN          NaN          NaN
# 12          NaN          NaN          NaN          NaN
# 13          NaN          NaN          NaN          NaN
# 14          NaN          NaN          NaN          NaN
# 15          NaN          NaN          NaN          NaN
# 16          NaN          NaN          NaN          NaN
# 17          NaN          NaN          NaN          NaN
# 18          NaN          NaN          NaN          NaN
# 19          NaN          NaN          NaN          NaN
# 20          NaN          NaN          NaN          NaN
# 21          NaN          NaN          NaN          NaN
# 22          NaN          NaN          NaN          NaN
# 23          NaN          NaN          NaN          NaN
# 24          NaN          NaN          NaN          NaN
# 25          NaN          NaN          NaN          NaN
# 26          NaN          NaN          NaN          NaN
# 27          NaN          NaN          NaN          NaN
# 28          NaN          NaN          NaN          NaN
# 29          NaN          NaN          NaN          NaN
# 30          NaN          NaN          NaN          NaN
#
# [31 rows x 27 columns]

# %%
#look for any NaN values in the column 'date' or 'Longitude' or 'Latitude' in df_merged and drop them
df = df.dropna(subset=['Date', 'Longitude', 'Latitude']).reset_index(drop=True)
#drop any columns that have 'Unnamed:' in the column name
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df
# Out:
#             ID   Latitude   Longitude   Class        Date     Site  \
# 0  wilkerson-0  19.899304  102.140084    sand  2022-02-25  fluvial
# 1  wilkerson-1  28.858429   70.391257    sand  2021-04-25  fluvial
# 2  wilkerson-2   9.141009    4.797954    sand  2021-04-30  fluvial
# 3  wilkerson-3  25.961395   80.159471    sand  2022-11-30  fluvial
# 4  wilkerson-4  25.397259   85.948165    sand  2020-04-18  fluvial
# 5  wilkerson-5  29.406670   71.567847    sand  2022-10-25  fluvial
# 6  wilkerson-9  15.163073   75.885587    fine  2022-12-16  fluvial
# 7    chaplin-0  40.633863  -75.464181  gravel  2018-06-15  fluvial
#
#                         Source   Country    D50  Notes  \
# 0  Wilkerson and Parker (2011)      Laos   0.31    NaN
# 1  Wilkerson and Parker (2011)  Pakistan   0.18    NaN
# 2  Wilkerson and Parker (2011)   Nigeria   0.45    NaN
# 3  Wilkerson and Parker (2011)     India   0.18    NaN
# 4  Wilkerson and Parker (2011)     India   0.43    NaN
# 5  Wilkerson and Parker (2011)  Pakistan   0.17    NaN
# 6  Wilkerson and Parker (2011)     India   0.04    NaN
# 7               Chaplin (2005)       USA  38.20  118.0
#
#                                       Location Notes
# 0         Mekong River at Wat Sop (No: 00248; p. 71)
# 1                        Indus (at Hajipur) Pakistan
# 2              Niger River at Jebba, Nigeria (p. 72)
# 3             Yamuna (at Hamirpur, U.P. state) India
# 4            Ganga (at Mokameh in Bihar state) India
# 5  Sutlej (in Samasatta below railway bridge) Pak...
# 6  Bennihalli (above Railway Bridge, Gadag Hubli ...
# 7                              Clear signs of mining

# %%
assert(len(df[df['Date'].isna() | df['Longitude'].isna() | df['Latitude'].isna()]) == 0)

# %% [markdown]
# # Part II: Select subset for training

# %% [markdown]
# Here we iterate over the df and iteratively pick and adjust the locations we want to keep

# %%
df.columns
# Out:
# Index(['ID', 'Latitude', 'Longitude', 'Class', 'Date', 'Site', 'Source',
#        'Country', 'Notes'],
#       dtype='object')

# %%
try:
    ee.Initialize()
except Exception as e:
    ee.Authenticate()
    ee.Initialize()

# %%
output = df.copy()
output
# Out:
#             ID   Latitude   Longitude   Class        Date     Site  \
# 0  wilkerson-0  19.899304  102.140084    sand  2022-02-25  fluvial
# 1  wilkerson-1  28.858429   70.391257    sand  2021-04-25  fluvial
# 2  wilkerson-2   9.141009    4.797954    sand  2021-04-30  fluvial
# 3  wilkerson-3  25.961395   80.159471    sand  2022-11-30  fluvial
# 4  wilkerson-4  25.397259   85.948165    sand  2020-04-18  fluvial
# 5  wilkerson-5  29.406670   71.567847    sand  2022-10-25  fluvial
# 6  wilkerson-9  15.163073   75.885587    fine  2022-12-16  fluvial
# 7    chaplin-0  40.633863  -75.464181  gravel  2018-06-15  fluvial
#
#                         Source   Country    D50  Notes  \
# 0  Wilkerson and Parker (2011)      Laos   0.31    NaN
# 1  Wilkerson and Parker (2011)  Pakistan   0.18    NaN
# 2  Wilkerson and Parker (2011)   Nigeria   0.45    NaN
# 3  Wilkerson and Parker (2011)     India   0.18    NaN
# 4  Wilkerson and Parker (2011)     India   0.43    NaN
# 5  Wilkerson and Parker (2011)  Pakistan   0.17    NaN
# 6  Wilkerson and Parker (2011)     India   0.04    NaN
# 7               Chaplin (2005)       USA  38.20  118.0
#
#                                       Location Notes
# 0         Mekong River at Wat Sop (No: 00248; p. 71)
# 1                        Indus (at Hajipur) Pakistan
# 2              Niger River at Jebba, Nigeria (p. 72)
# 3             Yamuna (at Hamirpur, U.P. state) India
# 4            Ganga (at Mokameh in Bihar state) India
# 5  Sutlej (in Samasatta below railway bridge) Pak...
# 6  Bennihalli (above Railway Bridge, Gadag Hubli ...
# 7                              Clear signs of mining

# %%
# %reload_ext autoreload
import sand_classification as sc
import quality_mosaic as qm
import file_management as fm

# %%
INDEX = 0

# %%
sampling_buffer_m = 5
Map = geemap.Map()
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %% [markdown]
# ## Manual Loop
#
# Keep running the following 2 cells until you're done with the manual sampling.

# %%
#Uncomment to change the date of the image
output['Date'].iloc[INDEX] = '2022-10-14'
# output['ID'].iloc[INDEX] = 'ns-49'

# %%
s1_s2, sample = qm.get_s1s2_data(output, Map, INDEX, display_smap=False, mosaic_method='median', sampling_buffer_m=sampling_buffer_m, 
                                 max_search_window_months=3, median_samples=5,roi_buffer_m=5000, obia=True)
# Out:
# Index:  7  ID:  chaplin-0 Class:  gravel  Site:  fluvial
# Search window from 2022-07-14 to 2023-01-14

# %% [markdown]
# ## Use this immediately after the map is refreshed to either select or discard the sample
#
# INDEX will auto update on calling this function.
# It will also overwrite just the sheet if the same exists, but will preserve the other sheets in the book

# %%
output, INDEX = qm.get_training_sample(output, s1_s2, sample, Map, INDEX, display_clusters=False, obia=True)
# fm.write_to_excel(output, output_file_path, sheet_name)
with pd.ExcelWriter(output_file_path,engine="openpyxl",mode="a",if_sheet_exists="replace") as writer:
    output.to_excel(writer,sheet_name=sheet_name,index=False)
output.iloc[INDEX-1]
# Out:
# New marker accepted
# Kept Observation
# ID                              chaplin-0
# Latitude                        40.634518
# Longitude                      -75.464091
# Class                              gravel
# Date                           2022-10-14
# Site                              fluvial
# Source                     Chaplin (2005)
# Country                               USA
# D50                                  38.2
# Notes                               118.0
# Location Notes      Clear signs of mining
# B2_mean                       1481.864136
# B3_mean                       1831.106812
# B4_mean                       2106.776611
# B8_mean                        2422.76709
# B8A_mean                       2402.70874
# B11_mean                       2281.18457
# B12_mean                      2022.135864
# VV_mean                         -6.604371
# VH_mean                        -13.797893
# mTGSI_mean                        0.02255
# BSI_mean                         0.058389
# NDWI_mean                       -0.139592
# keep                                 True
# location_tweaked                     True
# class_code                              2
# Name: 7, dtype: object

# %% [markdown]
# ## Final Output

# %%
output
# Out:
#             ID   Latitude   Longitude   Class        Date     Site  \
# 0  wilkerson-0  19.899304  102.140084    sand  2022-02-25  fluvial
# 1  wilkerson-1  28.858429   70.391257    sand  2021-04-25  fluvial
# 2  wilkerson-2   9.141009    4.797954    sand  2021-04-30  fluvial
# 3  wilkerson-3  25.961395   80.159471    sand  2022-04-03  fluvial
# 4  wilkerson-4  25.397033   85.947653    sand  2020-04-18  fluvial
# 5  wilkerson-5  29.406617   71.567756    sand  2022-10-25  fluvial
# 6  wilkerson-9  15.163073   75.885587    fine  2022-12-16  fluvial
# 7    chaplin-0  40.633863  -75.464181  gravel  2018-06-15  fluvial
#
#                         Source   Country    D50  Notes  ...     B11_mean  \
# 0  Wilkerson and Parker (2011)      Laos   0.31    NaN  ...          NaN
# 1  Wilkerson and Parker (2011)  Pakistan   0.18    NaN  ...  3642.426270
# 2  Wilkerson and Parker (2011)   Nigeria   0.45    NaN  ...  2563.118408
# 3  Wilkerson and Parker (2011)     India   0.18    NaN  ...  4124.906738
# 4  Wilkerson and Parker (2011)     India   0.43    NaN  ...  4070.888916
# 5  Wilkerson and Parker (2011)  Pakistan   0.17    NaN  ...  3866.447510
# 6  Wilkerson and Parker (2011)     India   0.04    NaN  ...  2174.612305
# 7               Chaplin (2005)       USA  38.20  118.0  ...          NaN
#
#       B12_mean    VV_mean    VH_mean  mTGSI_mean  BSI_mean  NDWI_mean   keep  \
# 0          NaN        NaN        NaN         NaN       NaN        NaN  False
# 1  3725.152588 -18.692795 -25.229696    0.086209  0.098757  -0.080478   True
# 2  2469.901367 -18.459393 -26.943130    0.106122  0.145168  -0.028190   True
# 3  4101.604492 -19.557650 -26.804512    0.107884  0.131114  -0.159184   True
# 4  4067.142822 -17.832499 -28.141626    0.087083  0.106525  -0.089916   True
# 5  3733.923096 -17.220385 -27.744926    0.073709  0.100285  -0.052254   True
# 6  1625.705444 -10.930077 -18.549110   -0.015049  0.074415  -0.287985   True
# 7          NaN        NaN        NaN         NaN       NaN        NaN  False
#
#    location_tweaked  class_code
# 0             False          99
# 1             False           1
# 2             False           1
# 3             False           1
# 4              True           1
# 5              True           1
# 6             False           0
# 7             False          99
#
# [8 rows x 26 columns]
