# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")
from tqdm.notebook import tqdm
import time
from IPython.display import clear_output

import ee, geemap

# %%
# %load_ext autoreload
# %autoreload 2
import sys  
sys.path.insert(0, '../lib/')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %reload_ext autoreload
import sand_classification as sc
import quality_mosaic as qm

# %% [markdown]
# # Part I: Get the locations from Google Drive

# %%
sheet_id = '13nF_pJ02Bd70cDJamuKbvZIkIdJ-kOI4O3Cx9K7Wzos'
# sheet_id = '1XqOtPkiE_Q0dfGSoyxrH730RkwrTczcRbDeJJpqRByQ'
sheet_name = 'dingle2016'
drive_url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
drive_url
# Out:
# 'https://docs.google.com/spreadsheets/d/13nF_pJ02Bd70cDJamuKbvZIkIdJ-kOI4O3Cx9K7Wzos/gviz/tq?tqx=out:csv&sheet=dingle2016'

# %%
output_file_path = '../data/labels/gt-bands.xlsx'

# %%
#Read in a google sheets with the ground truth data from string drive_loc
df = pd.read_csv(drive_url)
df
# Out:
#                    ID   Latitude  Longitude   Class        Date     Site  \
# 0   dingle16-yamuna-0  30.290546  77.562991  gravel  2022-02-14  fluvial
# 1   dingle16-yamuna-1  30.260267  77.532841   other  2022-02-14  fluvial
# 2   dingle16-yamuna-2  30.171396  77.472709  gravel  2022-02-14  fluvial
# 3   dingle16-yamuna-3  30.148757  77.457765   other  2022-02-14  fluvial
# 4    dingle16-ganga-0  30.051389  78.276702   other  2022-11-15  fluvial
# 5    dingle16-ganga-1  29.906710  78.163542   other  2022-11-15  fluvial
# 6    dingle16-ganga-2  29.878889  78.172941   other  2022-11-15  fluvial
# 7    dingle16-ganga-3  29.787168  78.177354  gravel  2022-11-15  fluvial
# 8   dingle16-sharda-0  29.102294  80.142014   other  2022-05-13  fluvial
# 9   dingle16-sharda-1  29.072990  80.124145  gravel  2022-05-13  fluvial
# 10  dingle16-sharda-2  29.019676  80.099263   other  2022-05-13  fluvial
# 11  dingle16-sharda-3  28.940892  80.112761  gravel  2022-05-13  fluvial
# 12  dingle16-sharda-4  28.921049  80.113258  gravel  2022-05-13  fluvial
# 13  dingle16-sharda-5  28.816405  80.108971  gravel  2022-05-13  fluvial
# 14  dingle16-gandak-0  27.463468  83.941627  gravel  2017-05-06  fluvial
# 15    dingle16-kosi-0  26.843668  87.149207   other  2017-05-06  fluvial
# 16    dingle16-kosi-1  26.834979  87.143962   other  2017-05-06  fluvial
# 17    dingle16-kosi-2  26.811604  87.152455  gravel  2017-05-06  fluvial
# 18    dingle16-kosi-3  26.786351  87.123539  gravel  2017-05-06  fluvial
#
#                 Source Country   Notes  Distance Downstram of MFT (km)  ...  \
# 0   10.2475/08.2016.03   India  Yamuna                             1.5  ...
# 1   10.2475/08.2016.04   India  Yamuna                            12.7  ...
# 2   10.2475/08.2016.05   India  Yamuna                            26.1  ...
# 3   10.2475/08.2016.06   India  Yamuna                            32.0  ...
# 4   10.2475/08.2016.07   India   Ganga                            -4.3  ...
# 5   10.2475/08.2016.08   India   Ganga                             8.7  ...
# 6   10.2475/08.2016.09   India   Ganga                            11.7  ...
# 7   10.2475/08.2016.10   India   Ganga                            22.1  ...
# 8   10.2475/08.2016.11   India  Sharda                             2.0  ...
# 9   10.2475/08.2016.12   India  Sharda                             6.2  ...
# 10  10.2475/08.2016.13   India  Sharda                            13.6  ...
# 11  10.2475/08.2016.14   India  Sharda                            23.7  ...
# 12  10.2475/08.2016.15   India  Sharda                            26.2  ...
# 13  10.2475/08.2016.16   India  Sharda                            39.5  ...
# 14  10.2475/08.2016.17   India  Gandak                             0.0  ...
# 15  10.2475/08.2016.21   India    Kosi                             0.0  ...
# 16  10.2475/08.2016.22   India    Kosi                             1.2  ...
# 17  10.2475/08.2016.23   India    Kosi                            42.0  ...
# 18  10.2475/08.2016.24   India    Kosi                             8.8  ...
#
#     Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN          NaN
# 7           NaN          NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN          NaN
# 9           NaN          NaN          NaN          NaN          NaN
# 10          NaN          NaN          NaN          NaN          NaN
# 11          NaN          NaN          NaN          NaN          NaN
# 12          NaN          NaN          NaN          NaN          NaN
# 13          NaN          NaN          NaN          NaN          NaN
# 14          NaN          NaN          NaN          NaN          NaN
# 15          NaN          NaN          NaN          NaN          NaN
# 16          NaN          NaN          NaN          NaN          NaN
# 17          NaN          NaN          NaN          NaN          NaN
# 18          NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 24  Unnamed: 25  Unnamed: 26  Unnamed: 27  Unnamed: 28
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN          NaN
# 7           NaN          NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN          NaN
# 9           NaN          NaN          NaN          NaN          NaN
# 10          NaN          NaN          NaN          NaN          NaN
# 11          NaN          NaN          NaN          NaN          NaN
# 12          NaN          NaN          NaN          NaN          NaN
# 13          NaN          NaN          NaN          NaN          NaN
# 14          NaN          NaN          NaN          NaN          NaN
# 15          NaN          NaN          NaN          NaN          NaN
# 16          NaN          NaN          NaN          NaN          NaN
# 17          NaN          NaN          NaN          NaN          NaN
# 18          NaN          NaN          NaN          NaN          NaN
#
# [19 rows x 29 columns]

# %%
#look for any NaN values in the column 'date' or 'Longitude' or 'Latitude' in df_merged and drop them
df = df.dropna(subset=['Date', 'Longitude', 'Latitude']).reset_index(drop=True)
#drop any columns that have 'Unnamed:' in the column name
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df
# Out:
#                    ID   Latitude  Longitude   Class        Date     Site  \
# 0   dingle16-yamuna-0  30.290546  77.562991  gravel  2022-02-14  fluvial
# 1   dingle16-yamuna-1  30.260267  77.532841   other  2022-02-14  fluvial
# 2   dingle16-yamuna-2  30.171396  77.472709  gravel  2022-02-14  fluvial
# 3   dingle16-yamuna-3  30.148757  77.457765   other  2022-02-14  fluvial
# 4    dingle16-ganga-0  30.051389  78.276702   other  2022-11-15  fluvial
# 5    dingle16-ganga-1  29.906710  78.163542   other  2022-11-15  fluvial
# 6    dingle16-ganga-2  29.878889  78.172941   other  2022-11-15  fluvial
# 7    dingle16-ganga-3  29.787168  78.177354  gravel  2022-11-15  fluvial
# 8   dingle16-sharda-0  29.102294  80.142014   other  2022-05-13  fluvial
# 9   dingle16-sharda-1  29.072990  80.124145  gravel  2022-05-13  fluvial
# 10  dingle16-sharda-2  29.019676  80.099263   other  2022-05-13  fluvial
# 11  dingle16-sharda-3  28.940892  80.112761  gravel  2022-05-13  fluvial
# 12  dingle16-sharda-4  28.921049  80.113258  gravel  2022-05-13  fluvial
# 13  dingle16-sharda-5  28.816405  80.108971  gravel  2022-05-13  fluvial
# 14  dingle16-gandak-0  27.463468  83.941627  gravel  2017-05-06  fluvial
# 15    dingle16-kosi-0  26.843668  87.149207   other  2017-05-06  fluvial
# 16    dingle16-kosi-1  26.834979  87.143962   other  2017-05-06  fluvial
# 17    dingle16-kosi-2  26.811604  87.152455  gravel  2017-05-06  fluvial
# 18    dingle16-kosi-3  26.786351  87.123539  gravel  2017-05-06  fluvial
#
#                 Source Country   Notes  Distance Downstram of MFT (km)  \
# 0   10.2475/08.2016.03   India  Yamuna                             1.5
# 1   10.2475/08.2016.04   India  Yamuna                            12.7
# 2   10.2475/08.2016.05   India  Yamuna                            26.1
# 3   10.2475/08.2016.06   India  Yamuna                            32.0
# 4   10.2475/08.2016.07   India   Ganga                            -4.3
# 5   10.2475/08.2016.08   India   Ganga                             8.7
# 6   10.2475/08.2016.09   India   Ganga                            11.7
# 7   10.2475/08.2016.10   India   Ganga                            22.1
# 8   10.2475/08.2016.11   India  Sharda                             2.0
# 9   10.2475/08.2016.12   India  Sharda                             6.2
# 10  10.2475/08.2016.13   India  Sharda                            13.6
# 11  10.2475/08.2016.14   India  Sharda                            23.7
# 12  10.2475/08.2016.15   India  Sharda                            26.2
# 13  10.2475/08.2016.16   India  Sharda                            39.5
# 14  10.2475/08.2016.17   India  Gandak                             0.0
# 15  10.2475/08.2016.21   India    Kosi                             0.0
# 16  10.2475/08.2016.22   India    Kosi                             1.2
# 17  10.2475/08.2016.23   India    Kosi                            42.0
# 18  10.2475/08.2016.24   India    Kosi                             8.8
#
#            D84         D50
# 0   109.896376   60.547689
# 1   167.730356   87.426576
# 2    79.341293   37.791765
# 3    68.119692   33.824577
# 4   215.269482   89.884472
# 5   176.069353  109.896376
# 6   149.085899   97.005860
# 7    76.638637   37.791765
# 8   306.554548   83.865178
# 9    69.551031   24.761040
# 10  195.361179   96.335792
# 11   81.571880   52.709825
# 12  100.426765   54.948188
# 13   72.003743   46.850742
# 14   81.571880   82.710581
# 15  286.025507   85.035892
# 16  205.073889  111.430472
# 17   85.035892   42.224253
# 18  135.298309   63.557920

# %%
assert(len(df[df['Date'].isna() | df['Longitude'].isna() | df['Latitude'].isna()]) == 0)

# %% [markdown]
# # Part II: Select subset for training

# %% [markdown]
# Here we iterate over the df and iteratively pick and adjust the locations we want to keep

# %%
df.columns
# Out:
# Index(['ID', 'Latitude', 'Longitude', 'Class', 'Date', 'Site', 'Source',
#        'Country', 'Notes', 'Distance Downstram of MFT (km)', 'D84', 'D50'],
#       dtype='object')

# %%
ee.Initialize()
# ee.Authenticate()

# %%
output = df.copy()
output
# Out:
#                    ID   Latitude  Longitude   Class        Date     Site  \
# 0   dingle16-yamuna-0  30.290546  77.562991  gravel  2022-02-14  fluvial
# 1   dingle16-yamuna-1  30.260267  77.532841   other  2022-02-14  fluvial
# 2   dingle16-yamuna-2  30.171396  77.472709  gravel  2022-02-14  fluvial
# 3   dingle16-yamuna-3  30.148757  77.457765   other  2022-02-14  fluvial
# 4    dingle16-ganga-0  30.051389  78.276702   other  2022-11-15  fluvial
# 5    dingle16-ganga-1  29.906710  78.163542   other  2022-11-15  fluvial
# 6    dingle16-ganga-2  29.878889  78.172941   other  2022-11-15  fluvial
# 7    dingle16-ganga-3  29.787168  78.177354  gravel  2022-11-15  fluvial
# 8   dingle16-sharda-0  29.102294  80.142014   other  2022-05-13  fluvial
# 9   dingle16-sharda-1  29.072990  80.124145  gravel  2022-05-13  fluvial
# 10  dingle16-sharda-2  29.019676  80.099263   other  2022-05-13  fluvial
# 11  dingle16-sharda-3  28.940892  80.112761  gravel  2022-05-13  fluvial
# 12  dingle16-sharda-4  28.921049  80.113258  gravel  2022-05-13  fluvial
# 13  dingle16-sharda-5  28.816405  80.108971  gravel  2022-05-13  fluvial
# 14  dingle16-gandak-0  27.463468  83.941627  gravel  2017-05-06  fluvial
# 15    dingle16-kosi-0  26.843668  87.149207   other  2017-05-06  fluvial
# 16    dingle16-kosi-1  26.834979  87.143962   other  2017-05-06  fluvial
# 17    dingle16-kosi-2  26.811604  87.152455  gravel  2017-05-06  fluvial
# 18    dingle16-kosi-3  26.786351  87.123539  gravel  2017-05-06  fluvial
#
#                 Source Country   Notes  Distance Downstram of MFT (km)  \
# 0   10.2475/08.2016.03   India  Yamuna                             1.5
# 1   10.2475/08.2016.04   India  Yamuna                            12.7
# 2   10.2475/08.2016.05   India  Yamuna                            26.1
# 3   10.2475/08.2016.06   India  Yamuna                            32.0
# 4   10.2475/08.2016.07   India   Ganga                            -4.3
# 5   10.2475/08.2016.08   India   Ganga                             8.7
# 6   10.2475/08.2016.09   India   Ganga                            11.7
# 7   10.2475/08.2016.10   India   Ganga                            22.1
# 8   10.2475/08.2016.11   India  Sharda                             2.0
# 9   10.2475/08.2016.12   India  Sharda                             6.2
# 10  10.2475/08.2016.13   India  Sharda                            13.6
# 11  10.2475/08.2016.14   India  Sharda                            23.7
# 12  10.2475/08.2016.15   India  Sharda                            26.2
# 13  10.2475/08.2016.16   India  Sharda                            39.5
# 14  10.2475/08.2016.17   India  Gandak                             0.0
# 15  10.2475/08.2016.21   India    Kosi                             0.0
# 16  10.2475/08.2016.22   India    Kosi                             1.2
# 17  10.2475/08.2016.23   India    Kosi                            42.0
# 18  10.2475/08.2016.24   India    Kosi                             8.8
#
#            D84         D50
# 0   109.896376   60.547689
# 1   167.730356   87.426576
# 2    79.341293   37.791765
# 3    68.119692   33.824577
# 4   215.269482   89.884472
# 5   176.069353  109.896376
# 6   149.085899   97.005860
# 7    76.638637   37.791765
# 8   306.554548   83.865178
# 9    69.551031   24.761040
# 10  195.361179   96.335792
# 11   81.571880   52.709825
# 12  100.426765   54.948188
# 13   72.003743   46.850742
# 14   81.571880   82.710581
# 15  286.025507   85.035892
# 16  205.073889  111.430472
# 17   85.035892   42.224253
# 18  135.298309   63.557920

# %%
# %reload_ext autoreload
import sand_classification as sc
import quality_mosaic as qm
import file_management as fm

# %%
# INDEX = 0
sampling_buffer_m = 5
Map = geemap.Map()
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %% [markdown]
# ## Manual Loop
#
# Keep running the following 2 cells until you're done with the manual sampling.

# %%
#Uncomment to change the date of the image
output['Date'].iloc[INDEX] = '2018-12-11'

# %%
s1_s2, sample = qm.get_s1s2_data(output, Map, INDEX, display_smap=False, mosaic_method='median', sampling_buffer_m=sampling_buffer_m, 
                                 max_search_window_months=2, median_samples=5,roi_buffer_m=5000, obia=True)
# Out:
# Index:  18  ID:  dingle16-kosi-3 Class:  gravel  Site:  fluvial
# Search window from 2018-10-11 to 2019-02-11

# %% [markdown]
# ## Use this immediately after the map is refreshed to either select or discard the sample
#
# INDEX will auto update on calling this function.
# It will also overwrite just the sheet if the same exists, but will preserve the other sheets in the book

# %%
output, INDEX = qm.get_training_sample(output, s1_s2, sample, Map, INDEX, display_clusters=False, obia=True)
# fm.write_to_excel(output, output_file_path, sheet_name)
with pd.ExcelWriter(output_file_path,engine="openpyxl",mode="a",if_sheet_exists="replace") as writer:
    output.to_excel(writer,sheet_name=sheet_name,index=False)
output.iloc[INDEX-1]
# Out:
# New marker accepted
# Kept Observation
# ID                                   dingle16-kosi-3
# Latitude                                   26.787227
# Longitude                                  87.123686
# Class                                         gravel
# Date                                      2018-12-11
# Site                                         fluvial
# Source                            10.2475/08.2016.24
# Country                                        India
# Notes                                           Kosi
# Distance Downstram of MFT (km)                   8.8
# D84                                       135.298309
# D50                                         63.55792
# B2_mean                                  2387.865479
# B3_mean                                  2763.817139
# B4_mean                                   2986.87085
# B8_mean                                  3141.317139
# B8A_mean                                 3082.381836
# B11_mean                                 4161.795898
# B12_mean                                 4493.921875
# VV_mean                                   -12.579719
# VH_mean                                   -22.974859
# mTGSI_mean                                  0.123621
# BSI_mean                                    0.127686
# NDWI_mean                                   -0.06391
# keep                                            True
# location_tweaked                                True
# class_code                                         2
# Name: 18, dtype: object

# %% [markdown]
# ## Final Output

# %%
output
# Out:
#                    ID   Latitude  Longitude   Class        Date     Site  \
# 0   dingle16-yamuna-0  30.291460  77.561964  gravel  2022-02-14  fluvial
# 1   dingle16-yamuna-1  30.260467  77.531451   other  2022-02-14  fluvial
# 2   dingle16-yamuna-2  30.169525  77.476584  gravel  2022-02-14  fluvial
# 3   dingle16-yamuna-3  30.148757  77.457765   other  2022-02-14  fluvial
# 4    dingle16-ganga-0  30.050727  78.272932   other  2022-11-15  fluvial
# 5    dingle16-ganga-1  29.906995  78.163685   other  2022-11-15  fluvial
# 6    dingle16-ganga-2  29.878889  78.172941   other  2022-11-15  fluvial
# 7    dingle16-ganga-3  29.792369  78.173349  gravel  2022-11-15  fluvial
# 8   dingle16-sharda-0  29.102294  80.142014   other  2022-05-13  fluvial
# 9   dingle16-sharda-1  29.075778  80.123819  gravel  2022-05-13  fluvial
# 10  dingle16-sharda-2  29.020309  80.099432   other  2022-05-13  fluvial
# 11  dingle16-sharda-3  28.940892  80.112761  gravel  2022-11-15  fluvial
# 12  dingle16-sharda-4  28.920551  80.113148  gravel  2022-11-15  fluvial
# 13  dingle16-sharda-5  28.814700  80.110380  gravel  2022-11-15  fluvial
# 14  dingle16-gandak-0  27.463468  83.941627  gravel  2018-12-11  fluvial
# 15    dingle16-kosi-0  26.843668  87.149207   other  2018-12-11  fluvial
# 16    dingle16-kosi-1  26.834979  87.143962   other  2018-12-11  fluvial
# 17    dingle16-kosi-2  26.811374  87.152321  gravel  2018-12-11  fluvial
# 18    dingle16-kosi-3  26.787227  87.123686  gravel  2018-12-11  fluvial
#
#                 Source Country   Notes  Distance Downstram of MFT (km)  ...  \
# 0   10.2475/08.2016.03   India  Yamuna                             1.5  ...
# 1   10.2475/08.2016.04   India  Yamuna                            12.7  ...
# 2   10.2475/08.2016.05   India  Yamuna                            26.1  ...
# 3   10.2475/08.2016.06   India  Yamuna                            32.0  ...
# 4   10.2475/08.2016.07   India   Ganga                            -4.3  ...
# 5   10.2475/08.2016.08   India   Ganga                             8.7  ...
# 6   10.2475/08.2016.09   India   Ganga                            11.7  ...
# 7   10.2475/08.2016.10   India   Ganga                            22.1  ...
# 8   10.2475/08.2016.11   India  Sharda                             2.0  ...
# 9   10.2475/08.2016.12   India  Sharda                             6.2  ...
# 10  10.2475/08.2016.13   India  Sharda                            13.6  ...
# 11  10.2475/08.2016.14   India  Sharda                            23.7  ...
# 12  10.2475/08.2016.15   India  Sharda                            26.2  ...
# 13  10.2475/08.2016.16   India  Sharda                            39.5  ...
# 14  10.2475/08.2016.17   India  Gandak                             0.0  ...
# 15  10.2475/08.2016.21   India    Kosi                             0.0  ...
# 16  10.2475/08.2016.22   India    Kosi                             1.2  ...
# 17  10.2475/08.2016.23   India    Kosi                            42.0  ...
# 18  10.2475/08.2016.24   India    Kosi                             8.8  ...
#
#        B11_mean     B12_mean    VV_mean    VH_mean  mTGSI_mean  BSI_mean  \
# 0   2219.377197  2056.531250  -9.634685 -18.923203    0.046771  0.077873
# 1   2543.482666  2409.145264 -11.071243 -21.289553    0.057402  0.084440
# 2   2373.446533  2117.270508 -10.771582 -18.298353    0.053079  0.096637
# 3   2491.108398  2440.038330 -10.742876 -19.266701    0.065100  0.085396
# 4   3622.755615  3593.545410 -11.001678 -18.943886    0.068214  0.085928
# 5   3604.649902  3512.469971 -10.806618 -19.392317    0.071000  0.094782
# 6   2465.141357  2261.391357  -7.834619 -16.453497    0.078138  0.120290
# 7   3489.370117  3545.863525  -8.715953 -17.023262    0.098847  0.115525
# 8   3207.373779  3220.383057 -13.895819 -25.606272    0.092357  0.111749
# 9   3055.792969  3083.984375 -14.740812 -25.136497    0.093375  0.111227
# 10  3298.793945  3087.833252  -7.853888 -16.977434    0.073661  0.108628
# 11  2968.109375  2827.766113 -16.845791 -25.941261    0.066905  0.096332
# 12  3335.596924  3342.504639 -14.582083 -23.899120    0.084015  0.101951
# 13  3585.627686  3541.282715 -15.861053 -26.538170    0.063193  0.081086
# 14  3452.605469  3441.082520 -13.684146 -21.052593    0.091866  0.112614
# 15  3704.494629  3895.872803 -12.546567 -23.321003    0.118077  0.128481
# 16  3513.874512  3639.814941 -11.544634 -20.679178    0.108387  0.121604
# 17  3962.000000  4239.803223 -10.559549 -20.337957    0.124516  0.131277
# 18  4161.795898  4493.921875 -12.579719 -22.974859    0.123621  0.127686
#
#     NDWI_mean  keep  location_tweaked  class_code
# 0   -0.121202  True              True           2
# 1   -0.110341  True              True           7
# 2   -0.161785  True              True           2
# 3   -0.098332  True             False           7
# 4   -0.055919  True              True           7
# 5   -0.082510  True              True           7
# 6   -0.155407  True             False           7
# 7   -0.095676  True              True           2
# 8   -0.068376  True             False           7
# 9   -0.071061  True              True           2
# 10  -0.088038  True              True           7
# 11  -0.059184  True             False           2
# 12  -0.082498  True              True           2
# 13  -0.066916  True              True           2
# 14  -0.101274  True             False           2
# 15  -0.076358  True             False           7
# 16  -0.079106  True             False           7
# 17  -0.079487  True              True           2
# 18  -0.063910  True              True           2
#
# [19 rows x 27 columns]
