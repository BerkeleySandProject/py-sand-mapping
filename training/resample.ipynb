# %% [markdown]
# # Resampling
#
# This notebooks allows the user to resample the ground truth in case they want to change some aspect. Most common use of this tool is to resample with changed SNIC parameters, and that's what will be explored here

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import geemap, ee

from geemap import cartoee
import cartopy.io.img_tiles as cimgt
import cartopy.crs as ccrs

import warnings
warnings.filterwarnings("ignore")

from tqdm.notebook import tqdm

# %%
# %load_ext autoreload
# %autoreload 2
import sys  
sys.path.insert(0, '../lib/')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %reload_ext autoreload
# import sand_classification as sc
import quality_mosaic as qm
import train_val as tv

# %%
try:
        ee.Initialize()
except Exception as e:
        ee.Authenticate()
        ee.Initialize()

# %%
df = tv.read_gt('../data/labels/23-07-26_gt-bands.xlsx', keep_columns=tv.resample_columns, zero_out=True)
df
# Out:
#      Longitude   Latitude  class_code         ID  keep        Date Class  \
# 0   -65.987196  18.459221           1  sedinet-1  True  2020-06-15  sand
# 1   -75.067643  38.665018           1  sedinet-2  True  2020-06-22  sand
# 2   -75.067228  38.665267           1  sedinet-3  True  2020-06-22  sand
# 3   -74.093250  39.792640           1  sedinet-5  True  2021-06-24  sand
# 4   -74.092864  39.792648           1  sedinet-6  True  2020-06-24  sand
# ..         ...        ...         ...        ...   ...         ...   ...
# 202  34.798517 -24.753306           1   Zavala-7  True  2023-05-11  Sand
# 203  34.798022 -24.753467           1   Zavala-8  True  2023-05-11  Sand
# 204  34.797492 -24.753653           1   Zavala-9  True  2023-05-11  Sand
# 205  34.796390 -24.754006           1  Zavala-11  True  2023-05-11  Sand
# 206  34.800027 -24.749152           1  Zavala-14  True  2023-05-11  Sand
#
#     B2_median B3_median B4_median  ... NDWI_median water_median trees_median  \
# 0        None      None      None  ...        None         None         None
# 1        None      None      None  ...        None         None         None
# 2        None      None      None  ...        None         None         None
# 3        None      None      None  ...        None         None         None
# 4        None      None      None  ...        None         None         None
# ..        ...       ...       ...  ...         ...          ...          ...
# 202      None      None      None  ...        None         None         None
# 203      None      None      None  ...        None         None         None
# 204      None      None      None  ...        None         None         None
# 205      None      None      None  ...        None         None         None
# 206      None      None      None  ...        None         None         None
#
#     grass_median flooded_vegetation_median crops_median  \
# 0           None                      None         None
# 1           None                      None         None
# 2           None                      None         None
# 3           None                      None         None
# 4           None                      None         None
# ..           ...                       ...          ...
# 202         None                      None         None
# 203         None                      None         None
# 204         None                      None         None
# 205         None                      None         None
# 206         None                      None         None
#
#     shrub_and_scrub_median built_median bare_median snow_and_ice_median
# 0                     None         None        None                None
# 1                     None         None        None                None
# 2                     None         None        None                None
# 3                     None         None        None                None
# 4                     None         None        None                None
# ..                     ...          ...         ...                 ...
# 202                   None         None        None                None
# 203                   None         None        None                None
# 204                   None         None        None                None
# 205                   None         None        None                None
# 206                   None         None        None                None
#
# [207 rows x 28 columns]

# %%
segmentation_size = 5 #pixels
max_search_window_months = 3
median_samples = 3

# %%
# df = df[100:102]
# df.reset_index(drop=True, inplace=True)
# df

# %%
#iterate over each row of df
for i, row in tqdm(df.iterrows(), total=df.shape[0]):
    print('Processing row: ', i)
    s1_s2_dw, sample = qm.get_s1s2_data(df, Map=None, index=i, display_smap=False, mosaic_method='median', 
                                 max_search_window_months=max_search_window_months, median_samples=median_samples,roi_buffer_m=5000, obia=True, interactive=False)
    if s1_s2_dw is not None:
        df, _ = qm.get_training_sample(df, s1_s2_dw, sample, Map=None, index=i, obia=True, size_seg_px=segmentation_size, interactive=False)
    else:
        print('No data for this sample')
# Out:
#   0%|          | 0/207 [00:00<?, ?it/s]
# Processing row:  0
# Search window from 2020-03-15 to 2020-09-15
# Processing row:  1
# Search window from 2020-03-22 to 2020-09-22
# Processing row:  2
# Search window from 2020-03-22 to 2020-09-22
# Processing row:  3
# Search window from 2021-03-24 to 2021-09-24
# Processing row:  4
# Search window from 2020-03-24 to 2020-09-24
# Processing row:  5
# Search window from 2020-04-06 to 2020-10-06
# Processing row:  6
# Search window from 2020-04-14 to 2020-10-14
# Processing row:  7
# Search window from 2020-04-14 to 2020-10-14
# Processing row:  8
# Search window from 2020-05-05 to 2020-11-05
# Processing row:  9
# Search window from 2020-05-05 to 2020-11-05
# Processing row:  10
# Search window from 2020-05-05 to 2020-11-05
# Processing row:  11
# Search window from 2020-05-20 to 2020-11-20
# Processing row:  12
# Search window from 2020-05-25 to 2020-11-25
# Processing row:  13
# Search window from 2020-06-02 to 2020-12-02
# Processing row:  14
# Search window from 2020-06-02 to 2020-12-02
# Processing row:  15
# Search window from 2020-06-02 to 2020-12-02
# Processing row:  16
# Search window from 2020-06-02 to 2020-12-02
# Processing row:  17
# Search window from 2020-06-02 to 2020-12-02
# Processing row:  18
# Search window from 2020-06-02 to 2020-12-02
# Processing row:  19
# Search window from 2020-06-02 to 2020-12-02
# Processing row:  20
# Search window from 2020-06-02 to 2020-12-02
# Processing row:  21
# Search window from 2020-06-02 to 2020-12-02
# Processing row:  22
# Search window from 2020-06-11 to 2020-12-11
# Processing row:  23
# Search window from 2020-06-02 to 2020-12-02
# Processing row:  24
# Search window from 2020-06-11 to 2020-12-11
# Processing row:  25
# Search window from 2020-06-11 to 2020-12-11
# Processing row:  26
# Search window from 2020-06-11 to 2020-12-11
# Processing row:  27
# Search window from 2020-06-11 to 2020-12-11
# Processing row:  28
# Search window from 2020-06-11 to 2020-12-11
# Processing row:  29
# Search window from 2020-06-30 to 2020-12-30
# Processing row:  30
# Search window from 2020-07-15 to 2021-01-15
# Processing row:  31
# Search window from 2020-07-29 to 2021-01-29
# Processing row:  32
# Search window from 2020-07-29 to 2021-01-29
# Processing row:  33
# Search window from 2020-08-13 to 2021-02-13
# Processing row:  34
# Search window from 2020-08-13 to 2021-02-13
# Processing row:  35
# Search window from 2020-08-16 to 2021-02-16
# Processing row:  36
# Search window from 2020-08-16 to 2021-02-16
# Processing row:  37
# Search window from 2020-09-22 to 2021-03-22
# Processing row:  38
# Search window from 2020-09-22 to 2021-03-22
# Processing row:  39
# Search window from 2020-09-22 to 2021-03-22
# Processing row:  40
# Search window from 2020-10-18 to 2021-04-18
# Processing row:  41
# Search window from 2020-12-13 to 2021-06-13
# Processing row:  42
# Search window from 2020-12-13 to 2021-06-13
# Processing row:  43
# Search window from 2021-02-28 to 2021-08-30
# Processing row:  44
# Search window from 2021-03-07 to 2021-09-07
# Processing row:  45
# Search window from 2021-03-28 to 2021-09-28
# Processing row:  46
# Search window from 2021-03-28 to 2021-09-28
# Processing row:  47
# Search window from 2021-03-28 to 2021-09-28
# Processing row:  48
# Search window from 2021-03-28 to 2021-09-28
# Processing row:  49
# Search window from 2021-03-28 to 2021-09-28
# Processing row:  50
# Search window from 2021-03-28 to 2021-09-28
# Processing row:  51
# Search window from 2019-11-12 to 2020-05-12
# Processing row:  52
# Search window from 2019-12-11 to 2020-06-11
# Processing row:  53
# Search window from 2019-12-11 to 2020-06-11
# Processing row:  54
# Search window from 2021-04-22 to 2021-10-22
# Processing row:  55
# Search window from 2022-04-22 to 2022-10-22
# Processing row:  56
# Search window from 2019-05-15 to 2019-11-15
# Processing row:  57
# Search window from 2019-05-15 to 2019-11-15
# Processing row:  58
# Search window from 2021-04-22 to 2021-10-22
# Processing row:  59
# Search window from 2022-04-22 to 2022-10-22
# Processing row:  60
# Search window from 2020-02-29 to 2020-08-31
# Processing row:  61
# Search window from 2021-09-07 to 2022-03-07
# Processing row:  62
# Search window from 2021-09-07 to 2022-03-07
# Processing row:  63
# Search window from 2021-09-07 to 2022-03-07
# Processing row:  64
# Search window from 2021-09-07 to 2022-03-07
# Processing row:  65
# Search window from 2021-09-07 to 2022-03-07
# Processing row:  66
# Search window from 2021-09-07 to 2022-03-07
# Processing row:  67
# Search window from 2020-09-05 to 2021-03-05
# Processing row:  68
# Search window from 2020-10-06 to 2021-04-06
# Processing row:  69
# Search window from 2020-10-06 to 2021-04-06
# Processing row:  70
# Search window from 2020-09-23 to 2021-03-23
# Processing row:  71
# Search window from 2020-09-23 to 2021-03-23
# Processing row:  72
# Search window from 2019-01-08 to 2019-07-08
# Processing row:  73
# Search window from 2019-01-08 to 2019-07-08
# Processing row:  74
# Search window from 2019-01-08 to 2019-07-08
# Processing row:  75
# Search window from 2019-01-08 to 2019-07-08
# Processing row:  76
# Search window from 2021-11-14 to 2022-05-14
# Processing row:  77
# Search window from 2021-11-14 to 2022-05-14
# Processing row:  78
# Search window from 2021-11-14 to 2022-05-14
# Processing row:  79
# Search window from 2021-11-14 to 2022-05-14
# Processing row:  80
# Search window from 2022-08-15 to 2023-02-15
# Processing row:  81
# Search window from 2022-08-15 to 2023-02-15
# Processing row:  82
# Search window from 2022-08-15 to 2023-02-15
# Processing row:  83
# Search window from 2022-08-15 to 2023-02-15
# Processing row:  84
# Search window from 2022-02-13 to 2022-08-13
# Processing row:  85
# Search window from 2022-02-13 to 2022-08-13
# Processing row:  86
# Search window from 2022-02-13 to 2022-08-13
# Processing row:  87
# Search window from 2022-08-15 to 2023-02-15
# Processing row:  88
# Search window from 2022-08-15 to 2023-02-15
# Processing row:  89
# Search window from 2022-08-15 to 2023-02-15
# Processing row:  90
# Search window from 2018-09-11 to 2019-03-11
# Processing row:  91
# Search window from 2018-09-11 to 2019-03-11
# Processing row:  92
# Search window from 2018-09-11 to 2019-03-11
# Processing row:  93
# Search window from 2018-09-11 to 2019-03-11
# Processing row:  94
# Search window from 2018-09-11 to 2019-03-11
# Processing row:  95
# Search window from 2022-07-03 to 2023-01-03
# Processing row:  96
# Search window from 2020-09-11 to 2021-03-11
# Processing row:  97
# Search window from 2021-11-19 to 2022-05-19
# Processing row:  98
# Search window from 2021-11-19 to 2022-05-19
# Processing row:  99
# Search window from 2021-10-02 to 2022-04-02
# Processing row:  100
# Search window from 2020-02-11 to 2020-08-11
# Processing row:  101
# Search window from 2021-04-11 to 2021-10-11
# Processing row:  102
# Search window from 2020-06-08 to 2020-12-08
# Processing row:  103
# Search window from 2019-10-02 to 2020-04-02
# Processing row:  104
# Search window from 2019-10-02 to 2020-04-02
# Processing row:  105
# Search window from 2022-05-12 to 2022-11-12
# Processing row:  106
# Search window from 2022-07-01 to 2023-01-01
# Processing row:  107
# Search window from 2022-07-01 to 2023-01-01
# Processing row:  108
# Search window from 2022-06-27 to 2022-12-27
# Processing row:  109
# Search window from 2022-06-27 to 2022-12-27
# Processing row:  110
# Search window from 2021-07-31 to 2022-01-31
# Processing row:  111
# Search window from 2021-07-31 to 2022-01-31
# Processing row:  112
# Search window from 2022-09-11 to 2023-03-11
# Processing row:  113
# Search window from 2022-09-11 to 2023-03-11
# Processing row:  114
# Search window from 2021-09-11 to 2022-03-11
# Processing row:  115
# Search window from 2022-02-24 to 2022-08-24
# Processing row:  116
# Search window from 2021-12-22 to 2022-06-22
# Processing row:  117
# Search window from 2022-08-16 to 2023-02-16
# Processing row:  118
# Search window from 2020-11-20 to 2021-05-20
# Processing row:  119
# Search window from 2021-02-23 to 2021-08-23
# Processing row:  120
# Search window from 2020-12-01 to 2021-06-01
# Processing row:  121
# Search window from 2021-07-22 to 2022-01-22
# Processing row:  122
# Search window from 2021-07-22 to 2022-01-22
# Processing row:  123
# Search window from 2022-04-15 to 2022-10-15
# Processing row:  124
# Search window from 2022-04-15 to 2022-10-15
# Processing row:  125
# Search window from 2022-04-15 to 2022-10-15
# Processing row:  126
# Search window from 2022-04-15 to 2022-10-15
# Processing row:  127
# Search window from 2022-03-25 to 2022-09-25
# Processing row:  128
# Search window from 2022-06-21 to 2022-12-21
# Processing row:  129
# Search window from 2022-06-21 to 2022-12-21
# Processing row:  130
# Search window from 2022-06-21 to 2022-12-21
# Processing row:  131
# Search window from 2020-05-15 to 2020-11-15
# Processing row:  132
# Search window from 2020-05-15 to 2020-11-15
# Processing row:  133
# Search window from 2021-04-11 to 2021-10-11
# Processing row:  134
# Search window from 2021-04-11 to 2021-10-11
# Processing row:  135
# Search window from 2021-04-11 to 2021-10-11
# Processing row:  136
# Search window from 2021-05-06 to 2021-11-06
# Processing row:  137
# Search window from 2021-05-06 to 2021-11-06
# Processing row:  138
# Search window from 2021-04-11 to 2021-10-11
# Processing row:  139
# Search window from 2022-04-16 to 2022-10-16
# Processing row:  140
# Search window from 2019-05-08 to 2019-11-08
# Processing row:  141
# Search window from 2020-06-15 to 2020-12-15
# Processing row:  142
# Search window from 2020-05-13 to 2020-11-13
# Processing row:  143
# Search window from 2022-06-21 to 2022-12-21
# Processing row:  144
# Search window from 2022-06-21 to 2022-12-21
# Processing row:  145
# Search window from 2022-06-21 to 2022-12-21
# Processing row:  146
# Search window from 2022-06-21 to 2022-12-21
# Processing row:  147
# Search window from 2022-06-21 to 2022-12-21
# Processing row:  148
# Search window from 2022-06-21 to 2022-12-21
# Processing row:  149
# Search window from 2020-02-21 to 2020-08-21
# Processing row:  150
# Search window from 2020-02-21 to 2020-08-21
# Processing row:  151
# Search window from 2020-02-21 to 2020-08-21
# Processing row:  152
# Search window from 2017-07-03 to 2018-01-03
# Processing row:  153
# Search window from 2020-11-13 to 2021-05-13
# Processing row:  154
# Search window from 2020-11-13 to 2021-05-13
# Processing row:  155
# Search window from 2020-11-13 to 2021-05-13
# Processing row:  156
# Search window from 2022-02-21 to 2022-08-21
# No data for this sample
# Processing row:  157
# Search window from 2022-01-02 to 2022-07-02
# Processing row:  158
# Search window from 2022-01-02 to 2022-07-02
# Processing row:  159
# Search window from 2022-01-02 to 2022-07-02
# Processing row:  160
# Search window from 2022-01-02 to 2022-07-02
# Processing row:  161
# Search window from 2022-06-04 to 2022-12-04
# Processing row:  162
# Search window from 2022-07-03 to 2023-01-03
# Processing row:  163
# Search window from 2022-07-03 to 2023-01-03
# Processing row:  164
# Search window from 2022-07-03 to 2023-01-03
# Processing row:  165
# Search window from 2022-07-03 to 2023-01-03
# Processing row:  166
# Search window from 2019-09-17 to 2020-03-17
# Processing row:  167
# Search window from 2019-09-17 to 2020-03-17
# Processing row:  168
# Search window from 2022-07-14 to 2023-01-14
# Processing row:  169
# Search window from 2022-07-14 to 2023-01-14
# Processing row:  170
# Search window from 2022-07-14 to 2023-01-14
# Processing row:  171
# Search window from 2022-01-06 to 2022-07-06
# No data for this sample
# Processing row:  172
# Search window from 2019-02-10 to 2019-08-10
# Processing row:  173
# Search window from 2021-04-05 to 2021-10-05
# Processing row:  174
# Search window from 2019-08-15 to 2020-02-15
# Processing row:  175
# Search window from 2019-08-15 to 2020-02-15
# Processing row:  176
# Search window from 2019-08-16 to 2020-02-16
# Processing row:  177
# Search window from 2020-10-04 to 2021-04-04
# Processing row:  178
# Search window from 2020-10-04 to 2021-04-04
# Processing row:  179
# Search window from 2020-02-15 to 2020-08-15
# Processing row:  180
# Search window from 2021-01-25 to 2021-07-25
# Processing row:  181
# Search window from 2021-01-30 to 2021-07-30
# Processing row:  182
# Search window from 2022-01-03 to 2022-07-03
# Processing row:  183
# Search window from 2020-01-18 to 2020-07-18
# Processing row:  184
# Search window from 2022-07-25 to 2023-01-25
# Processing row:  185
# Search window from 2022-07-14 to 2023-01-14
# Processing row:  186
# Search window from 2018-06-21 to 2018-12-21
# Processing row:  187
# Search window from 2018-06-20 to 2018-12-20
# Processing row:  188
# Search window from 2018-06-20 to 2018-12-20
# Processing row:  189
# Search window from 2018-06-20 to 2018-12-20
# Processing row:  190
# Search window from 2018-07-23 to 2019-01-23
# Processing row:  191
# Search window from 2018-07-24 to 2019-01-24
# Processing row:  192
# Search window from 2023-02-08 to 2023-08-08
# Processing row:  193
# Search window from 2023-02-11 to 2023-08-11
# Processing row:  194
# Search window from 2023-02-13 to 2023-08-13
# Processing row:  195
# Search window from 2023-02-14 to 2023-08-14
# Processing row:  196
# Search window from 2023-02-15 to 2023-08-15
# Processing row:  197
# Search window from 2023-02-18 to 2023-08-18
# Processing row:  198
# Search window from 2023-02-19 to 2023-08-19
# Processing row:  199
# Search window from 2023-02-11 to 2023-08-11
# Processing row:  200
# Search window from 2023-02-11 to 2023-08-11
# Processing row:  201
# Search window from 2023-02-11 to 2023-08-11
# Processing row:  202
# Search window from 2023-02-11 to 2023-08-11
# Processing row:  203
# Search window from 2023-02-11 to 2023-08-11
# Processing row:  204
# Search window from 2023-02-11 to 2023-08-11
# Processing row:  205
# Search window from 2023-02-11 to 2023-08-11
# Processing row:  206
# Search window from 2023-02-11 to 2023-08-11

# %%
df
# Out:
#      Longitude   Latitude  class_code         ID  keep        Date Class  \
# 0   -65.987196  18.459221           1  sedinet-1  True  2020-06-15  sand
# 1   -75.067643  38.665018           1  sedinet-2  True  2020-06-22  sand
# 2   -75.067228  38.665267           1  sedinet-3  True  2020-06-22  sand
# 3   -74.093250  39.792640           1  sedinet-5  True  2021-06-24  sand
# 4   -74.092864  39.792648           1  sedinet-6  True  2020-06-24  sand
# ..         ...        ...         ...        ...   ...         ...   ...
# 202  34.798517 -24.753306           1   Zavala-7  True  2023-05-11  Sand
# 203  34.798022 -24.753467           1   Zavala-8  True  2023-05-11  Sand
# 204  34.797492 -24.753653           1   Zavala-9  True  2023-05-11  Sand
# 205  34.796390 -24.754006           1  Zavala-11  True  2023-05-11  Sand
# 206  34.800027 -24.749152           1  Zavala-14  True  2023-05-11  Sand
#
#     B2_median B3_median B4_median  ... NDWI_median water_median trees_median  \
# 0        1645      2343      2934  ...   -0.170226      0.08414     0.038778
# 1        2617      3231      3834  ...   -0.199872     0.046431     0.022985
# 2        2384      2966      3580  ...    -0.20157     0.037595     0.016429
# 3        3304      3780      4300  ...    -0.15018     0.043509     0.020276
# 4        3210      3710      4192  ...    -0.14578     0.047825     0.022695
# ..        ...       ...       ...  ...         ...          ...          ...
# 202      1994      2830      3644  ...   -0.191518     0.045309     0.028198
# 203      1920      2744      3508  ...   -0.185723     0.035443     0.024025
# 204      1770      2554      3272  ...   -0.197193     0.043471     0.023897
# 205      1776      2556      3280  ...   -0.197098     0.042761     0.022884
# 206       622    1010.5      1214  ...   -0.493955     0.029491     0.048033
#
#     grass_median flooded_vegetation_median crops_median  \
# 0       0.046349                  0.037734     0.059408
# 1       0.027334                  0.033331     0.042793
# 2       0.025915                  0.028977     0.045596
# 3        0.02983                  0.028388     0.047001
# 4       0.033304                  0.028265     0.056938
# ..           ...                       ...          ...
# 202     0.025014                  0.032435     0.055887
# 203     0.023055                  0.029211     0.049712
# 204      0.02429                  0.036118     0.052919
# 205       0.0241                  0.036113     0.052513
# 206     0.083483                  0.029345     0.519369
#
#     shrub_and_scrub_median built_median bare_median snow_and_ice_median
# 0                 0.055884     0.392948     0.17713            0.049061
# 1                 0.054064     0.049722    0.533417            0.184304
# 2                 0.063974     0.035682    0.604572            0.131641
# 3                   0.0538     0.058212    0.480324            0.240375
# 4                 0.058323     0.061641    0.439562            0.247686
# ..                     ...          ...         ...                 ...
# 202               0.125305      0.05696    0.563004            0.051955
# 203               0.129282     0.060285    0.588263            0.051365
# 204               0.144833     0.049216    0.564172            0.047067
# 205               0.144833     0.048542    0.564975            0.046638
# 206               0.136085     0.057994    0.053757            0.038889
#
# [207 rows x 28 columns]

# %%
# remove all rows that have any NaN values
df2 = df.dropna().reset_index(drop=True)
df2
# Out:
#      Longitude   Latitude  class_code         ID  keep        Date Class  \
# 0   -65.987196  18.459221           1  sedinet-1  True  2020-06-15  sand
# 1   -75.067643  38.665018           1  sedinet-2  True  2020-06-22  sand
# 2   -75.067228  38.665267           1  sedinet-3  True  2020-06-22  sand
# 3   -74.093250  39.792640           1  sedinet-5  True  2021-06-24  sand
# 4   -74.092864  39.792648           1  sedinet-6  True  2020-06-24  sand
# ..         ...        ...         ...        ...   ...         ...   ...
# 200  34.798517 -24.753306           1   Zavala-7  True  2023-05-11  Sand
# 201  34.798022 -24.753467           1   Zavala-8  True  2023-05-11  Sand
# 202  34.797492 -24.753653           1   Zavala-9  True  2023-05-11  Sand
# 203  34.796390 -24.754006           1  Zavala-11  True  2023-05-11  Sand
# 204  34.800027 -24.749152           1  Zavala-14  True  2023-05-11  Sand
#
#     B2_median B3_median B4_median  ... NDWI_median water_median trees_median  \
# 0        1645      2343      2934  ...   -0.170226      0.08414     0.038778
# 1        2617      3231      3834  ...   -0.199872     0.046431     0.022985
# 2        2384      2966      3580  ...    -0.20157     0.037595     0.016429
# 3        3304      3780      4300  ...    -0.15018     0.043509     0.020276
# 4        3210      3710      4192  ...    -0.14578     0.047825     0.022695
# ..        ...       ...       ...  ...         ...          ...          ...
# 200      1994      2830      3644  ...   -0.191518     0.045309     0.028198
# 201      1920      2744      3508  ...   -0.185723     0.035443     0.024025
# 202      1770      2554      3272  ...   -0.197193     0.043471     0.023897
# 203      1776      2556      3280  ...   -0.197098     0.042761     0.022884
# 204       622    1010.5      1214  ...   -0.493955     0.029491     0.048033
#
#     grass_median flooded_vegetation_median crops_median  \
# 0       0.046349                  0.037734     0.059408
# 1       0.027334                  0.033331     0.042793
# 2       0.025915                  0.028977     0.045596
# 3        0.02983                  0.028388     0.047001
# 4       0.033304                  0.028265     0.056938
# ..           ...                       ...          ...
# 200     0.025014                  0.032435     0.055887
# 201     0.023055                  0.029211     0.049712
# 202      0.02429                  0.036118     0.052919
# 203       0.0241                  0.036113     0.052513
# 204     0.083483                  0.029345     0.519369
#
#     shrub_and_scrub_median built_median bare_median snow_and_ice_median
# 0                 0.055884     0.392948     0.17713            0.049061
# 1                 0.054064     0.049722    0.533417            0.184304
# 2                 0.063974     0.035682    0.604572            0.131641
# 3                   0.0538     0.058212    0.480324            0.240375
# 4                 0.058323     0.061641    0.439562            0.247686
# ..                     ...          ...         ...                 ...
# 200               0.125305      0.05696    0.563004            0.051955
# 201               0.129282     0.060285    0.588263            0.051365
# 202               0.144833     0.049216    0.564172            0.047067
# 203               0.144833     0.048542    0.564975            0.046638
# 204               0.136085     0.057994    0.053757            0.038889
#
# [205 rows x 28 columns]

# %% [markdown]
# ## Save to an excel sheet

# %%
postfix = 's' + str(segmentation_size)
output_file_path = '../data/labels/gt-bands-resampled-' + postfix + '-dw.xlsx'
postfix, output_file_path
# Out:
# ('s5', '../data/labels/gt-bands-resampled-s5-dw.xlsx')

# %%
# with pd.ExcelWriter(output_file_path,engine="openpyxl",mode="a",if_sheet_exists="replace") as writer:
#     df.to_excel(writer,sheet_name=postfix,index=False)

df2.to_excel(output_file_path,sheet_name=postfix,index=False)
